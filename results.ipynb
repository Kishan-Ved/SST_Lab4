# %%
import pandas as pd

# %%
df = pd.read_csv('./result_2.csv')

# %%
# df["Matches"] = df["Matches"].replace({True: "Yes", False: "No"})

# %%
df
# Out:
#                                  Old File Path  \
# 0                           tools/sort/sort.py
# 1                    lib/gui/control_helper.py
# 2                     plugins/train/_config.py
# 3                 plugins/train/model/_base.py
# 4     plugins/train/model/original_defaults.py
# ...                                        ...
# 2319                    tools/manual/manual.py
# 2320                   lib/align/alignments.py
# 2321       requirements/_requirements_base.txt
# 2322      .install/linux/faceswap_setup_x64.sh
# 2323                                 README.md
#
#                                  New File Path  \
# 0                           tools/sort/sort.py
# 1                    lib/gui/control_helper.py
# 2                     plugins/train/_config.py
# 3                 plugins/train/model/_base.py
# 4     plugins/train/model/original_defaults.py
# ...                                        ...
# 2319                    tools/manual/manual.py
# 2320                   lib/align/alignments.py
# 2321       requirements/_requirements_base.txt
# 2322      .install/linux/faceswap_setup_x64.sh
# 2323                                 README.md
#
#                                     Commit SHA  \
# 0     544a95bc4fc2d87e5a83b938ff5ccd328f02d4e4
# 1     46cb53e6f0266885239663258c57966cfe475c61
# 2     46cb53e6f0266885239663258c57966cfe475c61
# 3     46cb53e6f0266885239663258c57966cfe475c61
# 4     46cb53e6f0266885239663258c57966cfe475c61
# ...                                        ...
# 2319  b6ac7b8039a1474dfe1607601426289939b9b346
# 2320  3f53ee9cec6d77565fc5bc2b3c6edd885334615d
# 2321  6fe300e601258babcbd5f3099178bbb52ae0c63a
# 2322  cbaad146d5aca9bd714bb6c69b10dd7c02d88f9d
# 2323  41b61f96a48dc94b13957e76f4db99330188be8d
#
#                              Parent Commit SHA  \
# 0     86ac59678486f4584b02dd561db826b903346e19
# 1     544a95bc4fc2d87e5a83b938ff5ccd328f02d4e4
# 2     544a95bc4fc2d87e5a83b938ff5ccd328f02d4e4
# 3     544a95bc4fc2d87e5a83b938ff5ccd328f02d4e4
# 4     544a95bc4fc2d87e5a83b938ff5ccd328f02d4e4
# ...                                        ...
# 2319  ea63f1e64a206157b61eaff1329324f03b3a4bd3
# 2320  b6ac7b8039a1474dfe1607601426289939b9b346
# 2321  3f53ee9cec6d77565fc5bc2b3c6edd885334615d
# 2322  6fe300e601258babcbd5f3099178bbb52ae0c63a
# 2323  cbaad146d5aca9bd714bb6c69b10dd7c02d88f9d
#
#                                          Commit Message  \
# 0                                               linting
# 1     Training updates:\n  - Expose optimizer epsilo...
# 2     Training updates:\n  - Expose optimizer epsilo...
# 3     Training updates:\n  - Expose optimizer epsilo...
# 4     Training updates:\n  - Expose optimizer epsilo...
# ...                                                 ...
# 2319  bugfix: Manual tool. Allow working with image ...
# 2320  Bugfix: Convert - Correctly error if a valid m...
# 2321                                 pin numpy to < 2.0
# 2322        Bugfix: Linux installer - pin git to < 2.45
# 2323                                   Update README.md
#
#                                              Diff Myers  \
# 0     @@ -257,12 +257,12 @@ class Sort():\n         ...
# 1     @@ -57,14 +57,18 @@ def set_slider_rounding(va...
# 2     @@ -108,7 +108,7 @@ class Config(FaceswapConfi...
# 3     @@ -386,7 +386,8 @@ class ModelBase():\n      ...
# 4     @@ -33,6 +33,9 @@\n         rounding:  [partia...
# ...                                                 ...
# 2319  @@ -1,6 +1,5 @@\n #!/usr/bin/env python3\n-"""...
# 2320  @@ -407,8 +407,8 @@ class Alignments():\n     ...
# 2321  @@ -1,7 +1,7 @@\n tqdm>=4.65\n psutil>=5.9.0\n...
# 2322  @@ -380,7 +380,9 @@ activate_env() {\n install...
# 2323  @@ -1,4 +1,7 @@\n # deepfakes_faceswap\n+\n+##...
#
#                                          Diff Histogram Matches
# 0     @@ -257,12 +257,12 @@ class Sort():\n         ...     Yes
# 1     @@ -57,14 +57,18 @@ def set_slider_rounding(va...     Yes
# 2     @@ -108,7 +108,7 @@ class Config(FaceswapConfi...     Yes
# 3     @@ -386,7 +386,8 @@ class ModelBase():\n      ...     Yes
# 4     @@ -33,6 +33,9 @@\n         rounding:  [partia...     Yes
# ...                                                 ...     ...
# 2319  @@ -1,6 +1,5 @@\n #!/usr/bin/env python3\n-"""...     Yes
# 2320  @@ -407,8 +407,8 @@ class Alignments():\n     ...     Yes
# 2321  @@ -1,7 +1,7 @@\n tqdm>=4.65\n psutil>=5.9.0\n...     Yes
# 2322  @@ -380,7 +380,9 @@ activate_env() {\n install...     Yes
# 2323  @@ -1,4 +1,7 @@\n # deepfakes_faceswap\n+\n+##...     Yes
#
# [2324 rows x 8 columns]

# %%
# df = df.head(5)

# %%
df
# Out:
#                                  Old File Path  \
# 0                           tools/sort/sort.py
# 1                    lib/gui/control_helper.py
# 2                     plugins/train/_config.py
# 3                 plugins/train/model/_base.py
# 4     plugins/train/model/original_defaults.py
# ...                                        ...
# 2319                    tools/manual/manual.py
# 2320                   lib/align/alignments.py
# 2321       requirements/_requirements_base.txt
# 2322      .install/linux/faceswap_setup_x64.sh
# 2323                                 README.md
#
#                                  New File Path  \
# 0                           tools/sort/sort.py
# 1                    lib/gui/control_helper.py
# 2                     plugins/train/_config.py
# 3                 plugins/train/model/_base.py
# 4     plugins/train/model/original_defaults.py
# ...                                        ...
# 2319                    tools/manual/manual.py
# 2320                   lib/align/alignments.py
# 2321       requirements/_requirements_base.txt
# 2322      .install/linux/faceswap_setup_x64.sh
# 2323                                 README.md
#
#                                     Commit SHA  \
# 0     544a95bc4fc2d87e5a83b938ff5ccd328f02d4e4
# 1     46cb53e6f0266885239663258c57966cfe475c61
# 2     46cb53e6f0266885239663258c57966cfe475c61
# 3     46cb53e6f0266885239663258c57966cfe475c61
# 4     46cb53e6f0266885239663258c57966cfe475c61
# ...                                        ...
# 2319  b6ac7b8039a1474dfe1607601426289939b9b346
# 2320  3f53ee9cec6d77565fc5bc2b3c6edd885334615d
# 2321  6fe300e601258babcbd5f3099178bbb52ae0c63a
# 2322  cbaad146d5aca9bd714bb6c69b10dd7c02d88f9d
# 2323  41b61f96a48dc94b13957e76f4db99330188be8d
#
#                              Parent Commit SHA  \
# 0     86ac59678486f4584b02dd561db826b903346e19
# 1     544a95bc4fc2d87e5a83b938ff5ccd328f02d4e4
# 2     544a95bc4fc2d87e5a83b938ff5ccd328f02d4e4
# 3     544a95bc4fc2d87e5a83b938ff5ccd328f02d4e4
# 4     544a95bc4fc2d87e5a83b938ff5ccd328f02d4e4
# ...                                        ...
# 2319  ea63f1e64a206157b61eaff1329324f03b3a4bd3
# 2320  b6ac7b8039a1474dfe1607601426289939b9b346
# 2321  3f53ee9cec6d77565fc5bc2b3c6edd885334615d
# 2322  6fe300e601258babcbd5f3099178bbb52ae0c63a
# 2323  cbaad146d5aca9bd714bb6c69b10dd7c02d88f9d
#
#                                          Commit Message  \
# 0                                               linting
# 1     Training updates:\n  - Expose optimizer epsilo...
# 2     Training updates:\n  - Expose optimizer epsilo...
# 3     Training updates:\n  - Expose optimizer epsilo...
# 4     Training updates:\n  - Expose optimizer epsilo...
# ...                                                 ...
# 2319  bugfix: Manual tool. Allow working with image ...
# 2320  Bugfix: Convert - Correctly error if a valid m...
# 2321                                 pin numpy to < 2.0
# 2322        Bugfix: Linux installer - pin git to < 2.45
# 2323                                   Update README.md
#
#                                              Diff Myers  \
# 0     @@ -257,12 +257,12 @@ class Sort():\n         ...
# 1     @@ -57,14 +57,18 @@ def set_slider_rounding(va...
# 2     @@ -108,7 +108,7 @@ class Config(FaceswapConfi...
# 3     @@ -386,7 +386,8 @@ class ModelBase():\n      ...
# 4     @@ -33,6 +33,9 @@\n         rounding:  [partia...
# ...                                                 ...
# 2319  @@ -1,6 +1,5 @@\n #!/usr/bin/env python3\n-"""...
# 2320  @@ -407,8 +407,8 @@ class Alignments():\n     ...
# 2321  @@ -1,7 +1,7 @@\n tqdm>=4.65\n psutil>=5.9.0\n...
# 2322  @@ -380,7 +380,9 @@ activate_env() {\n install...
# 2323  @@ -1,4 +1,7 @@\n # deepfakes_faceswap\n+\n+##...
#
#                                          Diff Histogram Matches
# 0     @@ -257,12 +257,12 @@ class Sort():\n         ...     Yes
# 1     @@ -57,14 +57,18 @@ def set_slider_rounding(va...     Yes
# 2     @@ -108,7 +108,7 @@ class Config(FaceswapConfi...     Yes
# 3     @@ -386,7 +386,8 @@ class ModelBase():\n      ...     Yes
# 4     @@ -33,6 +33,9 @@\n         rounding:  [partia...     Yes
# ...                                                 ...     ...
# 2319  @@ -1,6 +1,5 @@\n #!/usr/bin/env python3\n-"""...     Yes
# 2320  @@ -407,8 +407,8 @@ class Alignments():\n     ...     Yes
# 2321  @@ -1,7 +1,7 @@\n tqdm>=4.65\n psutil>=5.9.0\n...     Yes
# 2322  @@ -380,7 +380,9 @@ activate_env() {\n install...     Yes
# 2323  @@ -1,4 +1,7 @@\n # deepfakes_faceswap\n+\n+##...     Yes
#
# [2324 rows x 8 columns]

# %%
import pandas as pd
from pydriller import Repository

def get_mcc(repo_path, commit_sha, file_path):
        for commit in Repository(repo_path, only_commits=commit_sha).traverse_commits():
            for mod in commit.modified_files:
                old_comp = 0
                if mod.new_path == file_path:
                    for it in mod.methods_before:
                        old_comp += it.complexity
                    print(old_comp)
                    return mod.complexity, old_comp
        return None, None

repo_path = "./faceswap"

for index, row in df.iterrows():
    a, b = get_mcc(repo_path, [row['Commit SHA']], row['New File Path'])
    print(a, b)

    if a is not None and b is not None:
        df.at[index, 'new_file_mcc'] = a
        df.at[index, 'old_file_mcc'] = b
# Out:
# 137
# 137 137
# 226
# 227 226
# 3
# 3 3
# 285
# 285 285
# 0
# 0 0
# 223
# 226 223
# 0
# None 0
# 0
# None 0
# 0
# None 0
# 0
# None 0
# 134
# 134 134
# 102
# 102 102
# 0
# None 0
# 0
# None 0
# 0
# None 0
# 0
# None 0
# 0
# None 0
# 0
# None 0
# None None
# 37
# 37 37
# 171
# 175 171
# 0
# 0 0
# 0
# 54 0
# 0
# 118 0
# None None
# 91
# 92 91
# 226
# 135 226
# 91
# 94 91
# 22
# 22 22
# 22
# 22 22
# 0
# None 0
# 102
# 102 102
# 203
# 205 203
# 0
# None 0
# 0
# None 0
# 0
# None 0
# 0
# None 0
# 0
# None 0
# 0
# None 0
#
# 0
# None 0
# 0
# None 0
# 0
# None 0
# 0
# None 0
# 0
# None 0
# 0
# None 0
# 0
# None 0
# 2
# 2 2
# 62
# 63 62
# 0
# None 0
# 192
# 195 192
# 125
# 126 125
# 95
# 95 95
# 68
# 68 68
# 53
# 53 53
# 68
# 68 68
# 52
# 52 52
# 56
# 56 56
# 67
# 67 67
# 71
# 71 71
# 141
# 141 141
# 0
# 30 0
# 111
# 81 111
# 82
# 82 82
# 0
# None 0
# 0
# None 0
# 0
# None 0

# %%
df.to_csv("final.csv", index=False)  # Saves without the index column

# %%
top_3 = df['New File Path'].value_counts().head(3)
top_3
# Out:
# New File Path
# setup.py                          44
# plugins/train/trainer/_base.py    28
# plugins/train/model/phaze_a.py    27
# Name: count, dtype: int64

# %%
df['New File Path'].value_counts().head(180)
# Out:
# New File Path
# setup.py                                    44
# plugins/train/trainer/_base.py              28
# plugins/train/model/phaze_a.py              27
# lib/training/generator.py                   25
# plugins/train/_config.py                    25
#                                             ..
# lib/gpu_stats.py                             4
# tests/lib/model/normalization_test.py        4
# tools/manual/frameviewer/editor/_base.py     4
# locales/kr/LC_MESSAGES/lib.cli.args.mo       4
# locales/kr/LC_MESSAGES/lib.cli.args.po       4
# Name: count, Length: 180, dtype: int64

# %%
from py2cfg import CFGBuilder

cfg = CFGBuilder().build_from_file('exampleCFG', './faceswap/tests/lib/model/normalization_test.py')
cfg

# %%
cfg.build_visual('exampleCFG', 'pdf')
# Out:
# 'exampleCFG.pdf'
# /snap/core20/current/lib/x86_64-linux-gnu/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libproxy.so.1)
# Failed to load module: /home/kishan/snap/code/common/.cache/gio-modules/libgiolibproxy.so
#
# (process:31875): Gtk-WARNING **: 02:05:53.436: Locale not supported by C library.
# 	Using the fallback 'C' locale.
# /home/kishan/snap/code/common/.cache/gio-modules/libgiolibproxy.so: cannot open shared object file: Permission denied
# Failed to load module: /home/kishan/snap/code/common/.cache/gio-modules/libgiolibproxy.so
#
# (evince:31875): Gtk-WARNING **: 02:05:53.530: Theme parsing error: gtk-keys.css:1:0: Failed to import: Error opening file /snap/code/181/usr/share/themes/Default/gtk-3.0/gtk-keys.css: Permission denied
# Gtk-Message: 02:05:53.530: Failed to load module "canberra-gtk-module"
# Gtk-Message: 02:05:53.533: Failed to load module "canberra-gtk-module"
# /home/kishan/snap/code/common/.cache/gio-modules/libdconfsettings.so: cannot open shared object file: Permission denied
# Failed to load module: /home/kishan/snap/code/common/.cache/gio-modules/libdconfsettings.so
#
# (evince:31875): Gtk-WARNING **: 02:05:54.134: Could not load a pixbuf from icon theme.
# This may indicate that pixbuf loaders or the mime database could not be found.

# %%
from py2cfg import CFGBuilder

code = """
from itertools import product

import numpy as np
import pytest

from tensorflow.keras import regularizers, models, layers  # noqa:E501  # pylint:disable=import-error

from lib.model import normalization
from lib.utils import get_backend

from tests.lib.model.layers_test import layer_test


@pytest.mark.parametrize('dummy', [None], ids=[get_backend().upper()])
def test_instance_normalization(dummy):  # pylint:disable=unused-argument

    layer_test(normalization.InstanceNormalization,
               kwargs={'epsilon': 0.1,
                       'gamma_regularizer': regularizers.l2(0.01),
                       'beta_regularizer': regularizers.l2(0.01)},
               input_shape=(3, 4, 2))
    layer_test(normalization.InstanceNormalization,
               kwargs={'epsilon': 0.1,
                       'axis': 1},
               input_shape=(1, 4, 1))
    layer_test(normalization.InstanceNormalization,
               kwargs={'gamma_initializer': 'ones',
                       'beta_initializer': 'ones'},
               input_shape=(3, 4, 2, 4))
    layer_test(normalization.InstanceNormalization,
               kwargs={'epsilon': 0.1,
                       'axis': 1,
                       'scale': False,
                       'center': False},
               input_shape=(3, 4, 2, 4))


@pytest.mark.parametrize('dummy', [None], ids=[get_backend().upper()])
def test_group_normalization(dummy):  # pylint:disable=unused-argument

    layer_test(normalization.GroupNormalization,
               kwargs={'epsilon': 0.1,
                       'gamma_regularizer': regularizers.l2(0.01),
                       'beta_regularizer': regularizers.l2(0.01)},
               input_shape=(4, 3, 4, 128))
    layer_test(normalization.GroupNormalization,
               kwargs={'epsilon': 0.1,
                       'axis': 1},
               input_shape=(4, 1, 4, 256))
    layer_test(normalization.GroupNormalization,
               kwargs={'gamma_init': 'ones',
                       'beta_init': 'ones'},
               input_shape=(4, 64))
    layer_test(normalization.GroupNormalization,
               kwargs={'epsilon': 0.1,
                       'axis': 1,
                       'group': 16},
               input_shape=(3, 64))


_PARAMS = ["center", "scale"]
_VALUES = list(product([True, False], repeat=len(_PARAMS)))
_IDS = [f"{'|'.join([_PARAMS[idx] for idx, b in enumerate(v) if b])}[{get_backend().upper()}]"
        for v in _VALUES]


@pytest.mark.parametrize(_PARAMS, _VALUES, ids=_IDS)
def test_adain_normalization(center, scale):

    norm = normalization.AdaInstanceNormalization(center=center, scale=scale)
    shapes = [(4, 8, 8, 1280), (4, 1, 1, 1280), (4, 1, 1, 1280)]
    norm.build(shapes)
    expected_output_shape = norm.compute_output_shape(shapes)
    inputs = [layers.Input(shape=shapes[0][1:]),
              layers.Input(shape=shapes[1][1:]),
              layers.Input(shape=shapes[2][1:])]
    model = models.Model(inputs, norm(inputs))
    data = [10 * np.random.random(shape) for shape in shapes]

    actual_output = model.predict(data, verbose=0)
    actual_output_shape = actual_output.shape

    for expected_dim, actual_dim in zip(expected_output_shape,
                                        actual_output_shape):
        if expected_dim is not None:
            assert expected_dim == actual_dim


_PARAMS = ["partial", "bias"]
_VALUES = [(0.0, False), (0.25, False), (0.5, True), (0.75, False), (1.0, True)]  # type:ignore
_IDS = [f"partial={v[0]}|bias={v[1]}[{get_backend().upper()}]" for v in _VALUES]


@pytest.mark.parametrize(_PARAMS, _VALUES, ids=_IDS)
def test_rms_normalization(partial, bias):  # pylint:disable=unused-argument

    layer_test(normalization.RMSNormalization,
               kwargs={"partial": partial, "bias": bias},
               input_shape=(4, 512))
"""

cfg = CFGBuilder().build_from_src('CFG4', code)
cfg.build_visual('CFG4', 'pdf')
# Out:
# 'CFG4.pdf'
# /snap/core20/current/lib/x86_64-linux-gnu/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libproxy.so.1)
# Failed to load module: /home/kishan/snap/code/common/.cache/gio-modules/libgiolibproxy.so
#
# (process:56917): Gtk-WARNING **: 02:25:59.553: Locale not supported by C library.
# 	Using the fallback 'C' locale.
# /home/kishan/snap/code/common/.cache/gio-modules/libgiolibproxy.so: cannot open shared object file: Permission denied
# Failed to load module: /home/kishan/snap/code/common/.cache/gio-modules/libgiolibproxy.so
#
# (evince:56917): Gtk-WARNING **: 02:25:59.655: Theme parsing error: gtk-keys.css:1:0: Failed to import: Error opening file /snap/code/181/usr/share/themes/Default/gtk-3.0/gtk-keys.css: Permission denied
# Gtk-Message: 02:25:59.656: Failed to load module "canberra-gtk-module"
# Gtk-Message: 02:25:59.666: Failed to load module "canberra-gtk-module"
# /home/kishan/snap/code/common/.cache/gio-modules/libdconfsettings.so: cannot open shared object file: Permission denied
# Failed to load module: /home/kishan/snap/code/common/.cache/gio-modules/libdconfsettings.so
#
# (evince:56917): Gtk-WARNING **: 02:26:00.337: Could not load a pixbuf from icon theme.
# This may indicate that pixbuf loaders or the mime database could not be found.

# %%
from py2cfg import CFGBuilder

code = """
from itertools import product

import numpy as np
import pytest

from lib.model import normalization
from lib.utils import get_backend

from tests.lib.model.layers_test import layer_test

if get_backend() == "amd":
    from keras import regularizers, models, layers
else:
    # Ignore linting errors from Tensorflow's thoroughly broken import system
    from tensorflow.keras import regularizers, models, layers  # pylint:disable=import-error


@pytest.mark.parametrize('dummy', [None], ids=[get_backend().upper()])
def test_instance_normalization(dummy):  # pylint:disable=unused-argument
    layer_test(normalization.InstanceNormalization,
               kwargs={'epsilon': 0.1,
                       'gamma_regularizer': regularizers.l2(0.01),
                       'beta_regularizer': regularizers.l2(0.01)},
               input_shape=(3, 4, 2))
    layer_test(normalization.InstanceNormalization,
               kwargs={'epsilon': 0.1,
                       'axis': 1},
               input_shape=(1, 4, 1))
    layer_test(normalization.InstanceNormalization,
               kwargs={'gamma_initializer': 'ones',
                       'beta_initializer': 'ones'},
               input_shape=(3, 4, 2, 4))
    layer_test(normalization.InstanceNormalization,
               kwargs={'epsilon': 0.1,
                       'axis': 1,
                       'scale': False,
                       'center': False},
               input_shape=(3, 4, 2, 4))


@pytest.mark.parametrize('dummy', [None], ids=[get_backend().upper()])
def test_group_normalization(dummy):  # pylint:disable=unused-argument
    layer_test(normalization.GroupNormalization,
               kwargs={'epsilon': 0.1,
                       'gamma_regularizer': regularizers.l2(0.01),
                       'beta_regularizer': regularizers.l2(0.01)},
               input_shape=(4, 3, 4, 128))
    layer_test(normalization.GroupNormalization,
               kwargs={'epsilon': 0.1,
                       'axis': 1},
               input_shape=(4, 1, 4, 256))
    layer_test(normalization.GroupNormalization,
               kwargs={'gamma_init': 'ones',
                       'beta_init': 'ones'},
               input_shape=(4, 64))
    layer_test(normalization.GroupNormalization,
               kwargs={'epsilon': 0.1,
                       'axis': 1,
                       'group': 16},
               input_shape=(3, 64))


_PARAMS = ["center", "scale"]
_VALUES = list(product([True, False], repeat=len(_PARAMS)))
_IDS = ["{}[{}]".format("|".join([_PARAMS[idx] for idx, b in enumerate(v) if b]),
                        get_backend().upper()) for v in _VALUES]


@pytest.mark.parametrize(_PARAMS, _VALUES, ids=_IDS)
def test_adain_normalization(center, scale):
    norm = normalization.AdaInstanceNormalization(center=center, scale=scale)
    shapes = [(4, 8, 8, 1280), (4, 1, 1, 1280), (4, 1, 1, 1280)]
    norm.build(shapes)
    expected_output_shape = norm.compute_output_shape(shapes)
    inputs = [layers.Input(shape=shapes[0][1:]),
              layers.Input(shape=shapes[1][1:]),
              layers.Input(shape=shapes[2][1:])]
    model = models.Model(inputs, norm(inputs))
    data = [10 * np.random.random(shape) for shape in shapes]

    actual_output = model.predict(data, verbose=0)
    actual_output_shape = actual_output.shape

    for expected_dim, actual_dim in zip(expected_output_shape,
                                        actual_output_shape):
        if expected_dim is not None:
            assert expected_dim == actual_dim


@pytest.mark.parametrize(_PARAMS, _VALUES, ids=_IDS)
def test_layer_normalization(center, scale):
    layer_test(normalization.LayerNormalization,
               kwargs={"center": center, "scale": scale},
               input_shape=(4, 512))


_PARAMS = ["partial", "bias"]
_VALUES = [(0.0, False), (0.25, False), (0.5, True), (0.75, False), (1.0, True)]  # type:ignore
_IDS = [f"partial={v[0]}|bias={v[1]}[{get_backend().upper()}]" for v in _VALUES]


@pytest.mark.parametrize(_PARAMS, _VALUES, ids=_IDS)
def test_rms_normalization(partial, bias):  # pylint:disable=unused-argument
    layer_test(normalization.RMSNormalization,
               kwargs={"partial": partial, "bias": bias},
               input_shape=(4, 512))
"""

cfg = CFGBuilder().build_from_src('CFG3', code)
cfg.build_visual('CFG3', 'pdf')
# Out:
# 'CFG3.pdf'
# /snap/core20/current/lib/x86_64-linux-gnu/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libproxy.so.1)
# Failed to load module: /home/kishan/snap/code/common/.cache/gio-modules/libgiolibproxy.so
#
# (process:62817): Gtk-WARNING **: 02:36:50.044: Locale not supported by C library.
# 	Using the fallback 'C' locale.
# /home/kishan/snap/code/common/.cache/gio-modules/libgiolibproxy.so: cannot open shared object file: Permission denied
# Failed to load module: /home/kishan/snap/code/common/.cache/gio-modules/libgiolibproxy.so
#
# (evince:62817): Gtk-WARNING **: 02:36:50.133: Theme parsing error: gtk-keys.css:1:0: Failed to import: Error opening file /snap/code/181/usr/share/themes/Default/gtk-3.0/gtk-keys.css: Permission denied
# Gtk-Message: 02:36:50.133: Failed to load module "canberra-gtk-module"
# Gtk-Message: 02:36:50.135: Failed to load module "canberra-gtk-module"
# /home/kishan/snap/code/common/.cache/gio-modules/libdconfsettings.so: cannot open shared object file: Permission denied
# Failed to load module: /home/kishan/snap/code/common/.cache/gio-modules/libdconfsettings.so
#
# (evince:62817): Gtk-WARNING **: 02:36:50.882: Could not load a pixbuf from icon theme.
# This may indicate that pixbuf loaders or the mime database could not be found.

# %%
from py2cfg import CFGBuilder

code = """
from itertools import product

import numpy as np
import pytest

from keras import regularizers, models, layers

from lib.model import normalization
from lib.utils import get_backend

from tests.lib.model.layers_test import layer_test


@pytest.mark.parametrize('dummy', [None], ids=[get_backend().upper()])
def test_instance_normalization(dummy):  # pylint:disable=unused-argument
    layer_test(normalization.InstanceNormalization,
               kwargs={'epsilon': 0.1,
                       'gamma_regularizer': regularizers.l2(0.01),
                       'beta_regularizer': regularizers.l2(0.01)},
               input_shape=(3, 4, 2))
    layer_test(normalization.InstanceNormalization,
               kwargs={'epsilon': 0.1,
                       'axis': 1},
               input_shape=(1, 4, 1))
    layer_test(normalization.InstanceNormalization,
               kwargs={'gamma_initializer': 'ones',
                       'beta_initializer': 'ones'},
               input_shape=(3, 4, 2, 4))
    layer_test(normalization.InstanceNormalization,
               kwargs={'epsilon': 0.1,
                       'axis': 1,
                       'scale': False,
                       'center': False},
               input_shape=(3, 4, 2, 4))


@pytest.mark.parametrize('dummy', [None], ids=[get_backend().upper()])
def test_group_normalization(dummy):  # pylint:disable=unused-argument
    layer_test(normalization.GroupNormalization,
               kwargs={'epsilon': 0.1,
                       'gamma_regularizer': regularizers.l2(0.01),
                       'beta_regularizer': regularizers.l2(0.01)},
               input_shape=(4, 3, 4, 128))
    layer_test(normalization.GroupNormalization,
               kwargs={'epsilon': 0.1,
                       'axis': 1},
               input_shape=(4, 1, 4, 256))
    layer_test(normalization.GroupNormalization,
               kwargs={'gamma_init': 'ones',
                       'beta_init': 'ones'},
               input_shape=(4, 64))
    layer_test(normalization.GroupNormalization,
               kwargs={'epsilon': 0.1,
                       'axis': 1,
                       'group': 16},
               input_shape=(3, 64))


_PARAMS = ["center", "scale"]
_VALUES = list(product([True, False], repeat=len(_PARAMS)))
_IDS = ["{}[{}]".format("|".join([_PARAMS[idx] for idx, b in enumerate(v) if b]),
                        get_backend().upper()) for v in _VALUES]


@pytest.mark.parametrize(_PARAMS, _VALUES, ids=_IDS)
def test_adain_normalization(center, scale):
    norm = normalization.AdaInstanceNormalization(center=center, scale=scale)
    shapes = [(4, 8, 8, 1280), (4, 1, 1, 1280), (4, 1, 1, 1280)]
    norm.build(shapes)
    expected_output_shape = norm.compute_output_shape(shapes)
    inputs = [layers.Input(shape=shapes[0][1:]),
              layers.Input(shape=shapes[1][1:]),
              layers.Input(shape=shapes[2][1:])]
    model = models.Model(inputs, norm(inputs))
    data = [10 * np.random.random(shape) for shape in shapes]

    actual_output = model.predict(data)
    actual_output_shape = actual_output.shape

    for expected_dim, actual_dim in zip(expected_output_shape,
                                        actual_output_shape):
        if expected_dim is not None:
            assert expected_dim == actual_dim


@pytest.mark.parametrize(_PARAMS, _VALUES, ids=_IDS)
def test_layer_normalization(center, scale):
    layer_test(normalization.LayerNormalization,
               kwargs={"center": center, "scale": scale},
               input_shape=(4, 512))


_PARAMS = ["partial", "bias"]
_VALUES = [(0.0, False), (0.25, False), (0.5, True), (0.75, False), (1.0, True)]
_IDS = ["partial={}|bias={}[{}]".format(v[0], v[1], get_backend().upper())
        for v in _VALUES]


@pytest.mark.parametrize(_PARAMS, _VALUES, ids=_IDS)
def test_rms_normalization(partial, bias):  # pylint:disable=unused-argument
    layer_test(normalization.RMSNormalization,
               kwargs={"partial": partial, "bias": bias},
               input_shape=(4, 512))
"""

cfg = CFGBuilder().build_from_src('CFG2', code)
cfg.build_visual('CFG2', 'pdf')
# Out:
# 'CFG2.pdf'
# /snap/core20/current/lib/x86_64-linux-gnu/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libproxy.so.1)
# Failed to load module: /home/kishan/snap/code/common/.cache/gio-modules/libgiolibproxy.so
#
# (process:65287): Gtk-WARNING **: 02:44:21.140: Locale not supported by C library.
# 	Using the fallback 'C' locale.
# /home/kishan/snap/code/common/.cache/gio-modules/libgiolibproxy.so: cannot open shared object file: Permission denied
# Failed to load module: /home/kishan/snap/code/common/.cache/gio-modules/libgiolibproxy.so
#
# (evince:65287): Gtk-WARNING **: 02:44:21.232: Theme parsing error: gtk-keys.css:1:0: Failed to import: Error opening file /snap/code/181/usr/share/themes/Default/gtk-3.0/gtk-keys.css: Permission denied
# Gtk-Message: 02:44:21.232: Failed to load module "canberra-gtk-module"
# Gtk-Message: 02:44:21.235: Failed to load module "canberra-gtk-module"
# /home/kishan/snap/code/common/.cache/gio-modules/libdconfsettings.so: cannot open shared object file: Permission denied
# Failed to load module: /home/kishan/snap/code/common/.cache/gio-modules/libdconfsettings.so
#
# (evince:65287): Gtk-WARNING **: 02:44:21.842: Could not load a pixbuf from icon theme.
# This may indicate that pixbuf loaders or the mime database could not be found.

# %%
from py2cfg import CFGBuilder

code = """
from keras import regularizers
import pytest

from lib.model import normalization
from lib.utils import get_backend

from .layers_test import layer_test


@pytest.mark.parametrize('dummy', [None], ids=[get_backend().upper()])
def test_instance_normalization(dummy):  # pylint:disable=unused-argument
    layer_test(normalization.InstanceNormalization,
               kwargs={'epsilon': 0.1,
                       'gamma_regularizer': regularizers.l2(0.01),
                       'beta_regularizer': regularizers.l2(0.01)},
               input_shape=(3, 4, 2))
    layer_test(normalization.InstanceNormalization,
               kwargs={'epsilon': 0.1,
                       'axis': 1},
               input_shape=(1, 4, 1))
    layer_test(normalization.InstanceNormalization,
               kwargs={'gamma_initializer': 'ones',
                       'beta_initializer': 'ones'},
               input_shape=(3, 4, 2, 4))
    layer_test(normalization.InstanceNormalization,
               kwargs={'epsilon': 0.1,
                       'axis': 1,
                       'scale': False,
                       'center': False},
               input_shape=(3, 4, 2, 4))
"""

cfg = CFGBuilder().build_from_src('CFG1', code)
cfg.build_visual('CFG1', 'pdf')
# Out:
# 'CFG1.pdf'
# /snap/core20/current/lib/x86_64-linux-gnu/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libproxy.so.1)
# Failed to load module: /home/kishan/snap/code/common/.cache/gio-modules/libgiolibproxy.so
#
# (process:64646): Gtk-WARNING **: 02:42:17.821: Locale not supported by C library.
# 	Using the fallback 'C' locale.
# /home/kishan/snap/code/common/.cache/gio-modules/libgiolibproxy.so: cannot open shared object file: Permission denied
# Failed to load module: /home/kishan/snap/code/common/.cache/gio-modules/libgiolibproxy.so
#
# (evince:64646): Gtk-WARNING **: 02:42:17.917: Theme parsing error: gtk-keys.css:1:0: Failed to import: Error opening file /snap/code/181/usr/share/themes/Default/gtk-3.0/gtk-keys.css: Permission denied
# Gtk-Message: 02:42:17.917: Failed to load module "canberra-gtk-module"
# Gtk-Message: 02:42:17.920: Failed to load module "canberra-gtk-module"
# /home/kishan/snap/code/common/.cache/gio-modules/libdconfsettings.so: cannot open shared object file: Permission denied
# Failed to load module: /home/kishan/snap/code/common/.cache/gio-modules/libdconfsettings.so
#
# (evince:64646): Gtk-WARNING **: 02:42:18.445: Could not load a pixbuf from icon theme.
# This may indicate that pixbuf loaders or the mime database could not be found.
